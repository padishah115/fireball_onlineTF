# %%
import os

network_path = r"\\eosproject-smb\eos\project\h\hiradmat\HRMT Experiments\2025\HRMT68 - FIREBALL 3\FB3 repository\HRMT68_data"

if os.path.exists(network_path):
    print("Network path exists. Listing contents:")
    for item in os.listdir(network_path):
        print(item)
else:
    print("Network path does not exist or is not accessible.")
# Out:
# Network path exists. Listing contents:
# andor_spectrometer
# BE-CEM-MTA
# cabletest
# chromox_cameras
# ldv_and_strain_gauges
# orca_streak
# plasmacell_cams
# rfpdu delay
# scope_lecroy
# scope_pool05710001
# scope_test
# spectrometer_cams
# tagged_data
# temperatures

# %%
import os
import winshell

path  ="H:\\project.lnk"

if os.path.exists(path):
    print("The path exists.")
    target  = winshell.shortcut(path)
    print("Target:", target.path)

path  ="\\eosproject-smb\eos\project"

if os.path.exists(path):
    print("The path exists.")
    target  = winshell.shortcut(path)
    print("Target:", target.path)
# Out:
# The path exists.
# Target: \\eosproject-smb\eos\project
