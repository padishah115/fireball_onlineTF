# %%
import os

# %%
parent_dir = "/eos/project/h/hiradmat/HRMT Experiments/2025/HRMT68 - FIREBALL 3/FB3 repository/HRMT68_data"
folder_name = "plasmacell_cams"

# %%
path = os.path.join(parent_dir, folder_name)
path
# Out:
# '/eos/project/h/hiradmat/HRMT Experiments/2025/HRMT68 - FIREBALL 3/FB3 repository/HRMT68_data/plasmacell_cams'

# %%
files = {
    f:os.stat(os.path.join(path, f)).st_mtime for f in os.listdir(path) if f.endswith(".csv") and 
    os.path.isfile(os.path.join(path, f))
}

files
# Out:
# {'HRM3_OD0_0_10000_1745407315968143_1745407309335000.csv': 1745407316.9361415,
#  'HRM3_OD0_0_10000_1745407339968133_1745407333335000.csv': 1745407340.9850523,
#  'HRM3_OD0_0_10000_1745407411968155_1745407405335000.csv': 1745407412.9792306,
#  'HRM3_OD0_0_10000_1745407435968144_1745407429335000.csv': 1745407436.928766,
#  'HRM3_OD0_0_10000_1745407459968159_1745407453335000.csv': 1745407460.943616,
#  'HRM3_OD0_0_10000_1745407483968153_1745407477335000.csv': 1745407485.003798,
#  'HRM3_OD0_0_10000_1745407531968147_1745407525335000.csv': 1745407532.9557865,
#  'HRM3_OD0_0_10000_1745407555968148_1745407549335000.csv': 1745407556.9796405,
#  'HRM3_OD0_0_10000_1745407579968134_1745407573335000.csv': 1745407580.9488726,
#  'HRM3_OD0_0_10000_1745407603968135_1745407597335000.csv': 1745407604.9708319,
#  'HRM3_OD0_0_10000_1745407627968136_1745407621335000.csv': 1745407628.9806166,
#  'HRM3_OD0_0_10000_1745407651968167_1745407645335000.csv': 1745407652.9497292,
# ...

# %%
files_sorted_by_unix =
